# %%
# install.packages('dummies')
# install.packages('stringi')
# install.packages('rpart.plot')
# install.packages('dplyr', repos = 'https://cloud.r-project.org')
# install.packages('caret', dependencies = TRUE)
# install.packages("C:\\Users\\antoi\\Downloads\\stringi_1.5.3.zip")
# install.packages('dplyr', repos = 'https://cloud.r-project.org')
# install.packages("doParallel")
library(tidyverse)

print(R.version$version.string)
training_set_labels <- read.csv(file = 'data/training_set_labels.csv', na.strings = c("", " ", "none", "unknown"))
test_set_values <- read.csv(file = 'data/test_set_values.csv', na.strings = c("", " ", "none", "unknown"))
training_set_values <- read.csv(file = 'data/training_set_values.csv',  na.strings = c("", " ", "none", "unknown"))

for (colname in names(training_set_values)) {
    list_of_unique <- unique(training_set_values[colname])
    if (nrow(list_of_unique) == 1){
        print(paste("the column", colname, "has always the same value"))
    }
}

training_set_values <- training_set_values[,setdiff(colnames(training_set_values),"recorded_by")] # remove recorded_by train_data

test_set_values <- test_set_values[,setdiff(colnames(test_set_values),"recorded_by")] # remove recorded_by _train_test

maxima <- c()
for (colname in names(training_set_values)) {
   maxima <- rbind(maxima, max(table(training_set_values[colname]))/59400)
}

# Shows it nicely
df <- data.frame(names(training_set_values), maxima)
df <- df[order(df$maxima, decreasing=TRUE),]
training_set_values <- training_set_values[,setdiff(colnames(training_set_values),"num_private")] # remove num_private train_set

test_set_values <- test_set_values[,setdiff(colnames(test_set_values),"num_private")] # remove num_private test_est
chisq.test(table(training_set_values$quantity, training_set_values$quantity_group))
chisq.test(table(training_set_values$quantity, training_set_values$payment_type))
chisq.test(table(training_set_values$funder, training_set_values$payment_type))
# table(training_set_values$funder, training_set_values$payment_type)  # We see that it's mostly random
chisq.test(table(training_set_values$water_quality, training_set_values$quality_group))

test_correlation <- cbind(training_set_values,training_set_labels[2])

chisq.test(table(test_correlation$amount_tsh, test_correlation$status_group))
chisq.test(table(test_correlation$date_recorded, test_correlation$status_group))
chisq.test(table(test_correlation$funder, test_correlation$status_group))
chisq.test(table(test_correlation$gps_height, test_correlation$status_group))
chisq.test(table(test_correlation$installer, test_correlation$status_group))
chisq.test(table(test_correlation$longitude, test_correlation$status_group))
chisq.test(table(test_correlation$latitude, test_correlation$status_group))
chisq.test(table(test_correlation$wpt_name, test_correlation$status_group))
chisq.test(table(test_correlation$basin, test_correlation$status_group))
chisq.test(table(test_correlation$subvillage, test_correlation$status_group))
chisq.test(table(test_correlation$region, test_correlation$status_group))
chisq.test(table(test_correlation$region_code, test_correlation$status_group))
chisq.test(table(test_correlation$district_code, test_correlation$status_group))
chisq.test(table(test_correlation$lga, test_correlation$status_group))
chisq.test(table(test_correlation$ward, test_correlation$status_group))
chisq.test(table(test_correlation$population, test_correlation$status_group))
chisq.test(table(test_correlation$public_meeting, test_correlation$status_group))
chisq.test(table(test_correlation$scheme_management, test_correlation$status_group))
chisq.test(table(test_correlation$scheme_name, test_correlation$status_group))
chisq.test(table(test_correlation$permit, test_correlation$status_group))
chisq.test(table(test_correlation$construction_year, test_correlation$status_group))
chisq.test(table(test_correlation$extraction_type, test_correlation$status_group))
chisq.test(table(test_correlation$management, test_correlation$status_group))
chisq.test(table(test_correlation$payment, test_correlation$status_group))
chisq.test(table(test_correlation$water_quality, test_correlation$status_group))
chisq.test(table(test_correlation$quantity, test_correlation$status_group))
chisq.test(table(test_correlation$source, test_correlation$status_group))
chisq.test(table(test_correlation$waterpoint_type, test_correlation$status_group))
options(repr.matrix.max.rows=10, repr.matrix.max.cols=100) # option pour la taille des prints



# table(training_set_values$waterpoint_type_group, training_set_values$waterpoint_type)  # less information
training_set_values <- training_set_values[,setdiff(colnames(training_set_values),"waterpoint_type_group")]
test_set_values <- test_set_values[,setdiff(colnames(test_set_values),"waterpoint_type_group")]

# table(training_set_values$source_type, training_set_values$source_class)  # less information
training_set_values <- training_set_values[,setdiff(colnames(training_set_values),"source_class")]
test_set_values <- test_set_values[,setdiff(colnames(test_set_values),"source_class")]

# table(training_set_values$source, training_set_values$source_type)  # less information
training_set_values <- training_set_values[,setdiff(colnames(training_set_values),"source_type")]
test_set_values <- test_set_values[,setdiff(colnames(test_set_values),"source_type")]

# table(training_set_values$water_quality, training_set_values$quality_group)  # less information
training_set_values <- training_set_values[,setdiff(colnames(training_set_values),"quality_group")]
test_set_values <- test_set_values[,setdiff(colnames(test_set_values),"quality_group")]

# table(training_set_values$quantity, training_set_values$quantity_group)  # equivalent, we delete column
training_set_values <- training_set_values[,setdiff(colnames(training_set_values),"quantity_group")]
test_set_values <- test_set_values[,setdiff(colnames(test_set_values),"quantity_group")]

# table(training_set_values$extraction_type, training_set_values$extraction_type_group)  # we can delete column
training_set_values <- training_set_values[,setdiff(colnames(training_set_values),"extraction_type_group")]
test_set_values <- test_set_values[,setdiff(colnames(test_set_values),"extraction_type_group")]

# table(training_set_values$extraction_type, training_set_values$extraction_type_class)  # We can delete column
# training_set_values <- training_set_values[,setdiff(colnames(training_set_values),"extraction_type_class")]

# table(training_set_values$payment, training_set_values$payment_type)  # equivalent,  we delete column
training_set_values <- training_set_values[,setdiff(colnames(training_set_values),"payment_type")]
test_set_values <- test_set_values[,setdiff(colnames(test_set_values),"payment_type")]

# table(training_set_values$management, training_set_values$management_group)  # we delete column
training_set_values <- training_set_values[,setdiff(colnames(training_set_values),"management_group")]
test_set_values <- test_set_values[,setdiff(colnames(test_set_values),"management_group")]

# table(training_set_values$region, training_set_values$region_code)  # very correlated but some cities/code are ambigius
# table(training_set_values$basin, training_set_values$subvillage)  # not really correlated, keep
# Out:
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.1 --
#
# v ggplot2 3.3.3     v purrr   0.3.4
# v tibble  3.1.1     v dplyr   1.0.6
# v tidyr   1.1.3     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# [1] "R version 3.6.3 (2020-02-29)"
# [1] "the column recorded_by has always the same value"
# 	Pearson's Chi-squared test
#
# data:  table(training_set_values$quantity, training_set_values$quantity_group)
# X-squared = 175833, df = 9, p-value < 2.2e-16
# 	Pearson's Chi-squared test
#
# data:  table(training_set_values$quantity, training_set_values$payment_type)
# X-squared = 1723.9, df = 15, p-value < 2.2e-16
# Warning message in chisq.test(table(training_set_values$funder, training_set_values$payment_type)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(training_set_values$funder, training_set_values$payment_type)
# X-squared = NaN, df = 9480, p-value = NA
# Warning message in chisq.test(table(training_set_values$water_quality, training_set_values$quality_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(training_set_values$water_quality, training_set_values$quality_group)
# X-squared = 230096, df = 24, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$amount_tsh, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$amount_tsh, test_correlation$status_group)
# X-squared = 4307.2, df = 194, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$date_recorded, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$date_recorded, test_correlation$status_group)
# X-squared = 5005.7, df = 710, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$funder, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$funder, test_correlation$status_group)
# X-squared = 14173, df = 3792, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$gps_height, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$gps_height, test_correlation$status_group)
# X-squared = 6279.7, df = 4854, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$installer, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$installer, test_correlation$status_group)
# X-squared = 14721, df = 4286, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$longitude, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$longitude, test_correlation$status_group)
# X-squared = 112780, df = 115030, p-value = 1
# Warning message in chisq.test(table(test_correlation$latitude, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$latitude, test_correlation$status_group)
# X-squared = 112782, df = 115032, p-value = 1
# Warning message in chisq.test(table(test_correlation$wpt_name, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$wpt_name, test_correlation$status_group)
# X-squared = 75575, df = 74796, p-value = 0.02224
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$basin, test_correlation$status_group)
# X-squared = 1921, df = 16, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$subvillage, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$subvillage, test_correlation$status_group)
# X-squared = 55053, df = 38572, p-value < 2.2e-16
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$region, test_correlation$status_group)
# X-squared = 4794.6, df = 40, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$region_code, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$region_code, test_correlation$status_group)
# X-squared = 5157.4, df = 52, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$district_code, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$district_code, test_correlation$status_group)
# X-squared = 1673.5, df = 38, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$lga, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$lga, test_correlation$status_group)
# X-squared = 11530, df = 248, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$ward, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$ward, test_correlation$status_group)
# X-squared = 26145, df = 4182, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$population, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$population, test_correlation$status_group)
# X-squared = 4480, df = 2096, p-value < 2.2e-16
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$public_meeting, test_correlation$status_group)
# X-squared = 302.18, df = 2, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$scheme_management, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$scheme_management, test_correlation$status_group)
# X-squared = 1887.1, df = 22, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$scheme_name, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$scheme_name, test_correlation$status_group)
# X-squared = 21616, df = 5388, p-value < 2.2e-16
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$permit, test_correlation$status_group)
# X-squared = 67.79, df = 2, p-value = 1.904e-15
# Warning message in chisq.test(table(test_correlation$construction_year, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$construction_year, test_correlation$status_group)
# X-squared = 4098.4, df = 108, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$extraction_type, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$extraction_type, test_correlation$status_group)
# X-squared = 7365.6, df = 34, p-value < 2.2e-16
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$management, test_correlation$status_group)
# X-squared = 2015.2, df = 20, p-value < 2.2e-16
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$payment, test_correlation$status_group)
# X-squared = 3334.7, df = 10, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$water_quality, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$water_quality, test_correlation$status_group)
# X-squared = 575.43, df = 12, p-value < 2.2e-16
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$quantity, test_correlation$status_group)
# X-squared = 11039, df = 6, p-value < 2.2e-16
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$source, test_correlation$status_group)
# X-squared = 2622.7, df = 16, p-value < 2.2e-16
# Warning message in chisq.test(table(test_correlation$waterpoint_type, test_correlation$status_group)):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  table(test_correlation$waterpoint_type, test_correlation$status_group)
# X-squared = 7450.3, df = 12, p-value < 2.2e-16

# %%
# Replacing NA values with "unknown"
i <- sapply(training_set_values, is.factor)
training_set_values[i] <- lapply(training_set_values[i], as.character)
training_set_values[is.na(training_set_values)] <- "unknown"
training_set_values[i] <- lapply(training_set_values[i], as.factor)
head(training_set_values)
# Out:
#   id    amount_tsh date_recorded funder              gps_height installer
# 1 69572 6000       2011-03-14    Roman               1390       Roman
# 2  8776    0       2013-03-06    Grumeti             1399       GRUMETI
# 3 34310   25       2013-02-25    Lottery Club         686       World vision
# 4 67743    0       2013-01-28    Unicef               263       UNICEF
# 5 19728    0       2011-07-13    Action In A            0       Artisan
# 6  9944   20       2011-03-13    Mkinga Distric Coun    0       DWE
#   longitude latitude   wpt_name             basin                   subvillage
# 1 34.93809   -9.856322 unknown              Lake Nyasa              Mnyusi B
# 2 34.69877   -2.147466 Zahanati             Lake Victoria           Nyamara
# 3 37.46066   -3.821329 Kwa Mahundi          Pangani                 Majengo
# 4 38.48616  -11.155298 Zahanati Ya Nanyumbu Ruvuma / Southern Coast Mahakamani
# 5 31.13085   -1.825359 Shuleni              Lake Victoria           Kyanyamisa
# 6 39.17280   -4.765587 Tajiri               Pangani                 Moa/Mwereme
#   region  region_code district_code lga       ward       population
# 1 Iringa  11           5            Ludewa    Mundindi   109
# 2 Mara    20           2            Serengeti Natta      280
# 3 Manyara 21           4            Simanjiro Ngorika    250
# 4 Mtwara  90          63            Nanyumbu  Nanyumbu    58
# 5 Kagera  18           1            Karagwe   Nyakasimbi   0
# 6 Tanga    4           8            Mkinga    Moa          1
#   public_meeting scheme_management scheme_name                 permit
# 1 True           VWC               Roman                       False
# 2 unknown        Other             unknown                     True
# 3 True           VWC               Nyumba ya mungu pipe scheme True
# 4 True           VWC               unknown                     True
# 5 True           unknown           unknown                     True
# 6 True           VWC               Zingibali                   True
#   construction_year extraction_type extraction_type_class management
# 1 1999              gravity         gravity               vwc
# 2 2010              gravity         gravity               wug
# 3 2009              gravity         gravity               vwc
# 4 1986              submersible     submersible           vwc
# 5    0              gravity         gravity               other
# 6 2009              submersible     submersible           vwc
#   payment        water_quality quantity     source
# 1 pay annually   soft          enough       spring
# 2 never pay      soft          insufficient rainwater harvesting
# 3 pay per bucket soft          enough       dam
# 4 never pay      soft          dry          machine dbh
# 5 never pay      soft          seasonal     rainwater harvesting
# 6 pay per bucket salty         enough       other
#   waterpoint_type
# 1 communal standpipe
# 2 communal standpipe
# 3 communal standpipe multiple
# 4 communal standpipe multiple
# 5 communal standpipe
# 6 communal standpipe multiple

# %%
library(dummies)

total_data <- rbind(training_set_values,test_set_values) # merge train and test to make dummies variable

factor_variables <- which(sapply(total_data[1,],class)=="factor") # take only factor variable
data_fact <- total_data[,factor_variables]

only_num_var <- total_data[,-factor_variables]

variables_to_keep <- c("permit", "quantity") # variable to transform

data_factor_onehot <- dummy.data.frame(data_fact[,variables_to_keep], sep="_")


data_factor_onehot[1:2,]

dim(total_data)
dim(training_set_values)

total_with_dummies <- cbind(only_num_var,data_factor_onehot)

# resplit data
# data_train
data_train <- total_with_dummies[1:59400,]
data_train <- cbind(data_train, training_set_labels[2])


# data_test
data_test <- total_with_dummies[59401:74250,]
# Out:
# dummies-1.5.6 provided by Decision Patterns
#
#
# Warning message in model.matrix.default(~x - 1, model.frame(~x - 1), contrasts = FALSE):
# "non-list contrasts argument ignored"
# Warning message in model.matrix.default(~x - 1, model.frame(~x - 1), contrasts = FALSE):
# "non-list contrasts argument ignored"
#   permit_False permit_True permit_unknown permit_NA quantity_dry
# 1 1            0           0              0         0
# 2 0            1           0              0         0
#   quantity_enough quantity_insufficient quantity_seasonal quantity_unknown
# 1 1               0                     0                 0
# 2 0               1                     0                 0
#   quantity_NA
# 1 0
# 2 0
# [1] 74250    30
# [1] 59400    30

# %%
# library(tidyverse)
#names(data_train) <- gsub(" ", "_", names(data_train))
names(data_train) <- make.names(names(data_train))
#names(data_test) <- gsub(" ", "_", names(data_test))
names(data_test) <- make.names(names(data_test))
data_test <- unique(data_test)
data_train <- unique(data_train)
head(data_train)
# Out:
#   id    amount_tsh gps_height longitude latitude   region_code district_code
# 1 69572 6000       1390       34.93809   -9.856322 11           5
# 2  8776    0       1399       34.69877   -2.147466 20           2
# 3 34310   25        686       37.46066   -3.821329 21           4
# 4 67743    0        263       38.48616  -11.155298 90          63
# 5 19728    0          0       31.13085   -1.825359 18           1
# 6  9944   20          0       39.17280   -4.765587  4           8
#   population construction_year permit_False permit_True permit_unknown
# 1 109        1999              1            0           0
# 2 280        2010              0            1           0
# 3 250        2009              0            1           0
# 4  58        1986              0            1           0
# 5   0           0              0            1           0
# 6   1        2009              0            1           0
#   permit_NA quantity_dry quantity_enough quantity_insufficient
# 1 0         0            1               0
# 2 0         0            0               1
# 3 0         0            1               0
# 4 0         1            0               0
# 5 0         0            0               0
# 6 0         0            1               0
#   quantity_seasonal quantity_unknown quantity_NA status_group
# 1 0                 0                0           functional
# 2 0                 0                0           functional
# 3 0                 0                0           functional
# 4 0                 0                0           non functional
# 5 1                 0                0           functional
# 6 0                 0                0           functional

# %%
# data_train <- sapply(data_train,function(x) as.numeric(as.character(x)))
# data_test  <-  sapply(data_test,function(x) as.numeric(as.character(x)))

# %%
# NAIVE BAYES
library(e1071)
library(caTools)
library(caret)

classifier <- naiveBayes(status_group~., data=data_train)
# print(classifier)

y_pred <- predict(classifier, newdata = data_test)
print(y_pred)

# confusion_matrix <- table(training_set_labels$status_group, y_pred)
# print(confusion_matrix)

# print(confusionMatrix(confusion_matrix))
# Out:
#     [1] functional              functional              functional
#     [4] non functional          functional              functional
#     [7] functional              non functional          non functional
#    [10] functional              functional              non functional
#    [13] non functional          functional              functional
#    [16] functional              functional              functional
#    [19] functional needs repair non functional          functional
#    [22] functional              functional              non functional
#    [25] functional              functional              non functional
#    [28] non functional          functional needs repair functional
#    [31] functional              functional              functional needs repair
#    [34] functional              functional              functional
#    [37] functional              functional              functional
#    [40] non functional          non functional          functional
#    [43] functional              non functional          functional
#    [46] non functional          functional              functional
#    [49] functional              functional              functional
#    [52] functional              functional              functional
#    [55] non functional          non functional          functional
#    [58] functional              functional              functional
#    [61] functional              non functional          functional
#    [64] non functional          functional              functional
#    [67] functional              functional              functional needs repair
#    [70] functional              functional              functional
#    [73] functional              non functional          functional
#    [76] functional              functional              functional
#    [79] functional              functional              functional
#    [82] functional              functional              functional
#    [85] functional              functional needs repair functional
#    [88] functional              functional              functional
#    [91] functional              functional              functional
#    [94] functional              functional              functional
#    [97] functional              functional              functional
#   [100] functional              functional              functional
#   [103] functional              functional              non functional
#   [106] functional              functional              functional
#   [109] functional              functional              functional
#   [112] non functional          functional              functional
#   [115] functional              functional              non functional
#   [118] functional              functional              functional
#   [121] functional              functional              functional
#   [124] functional              functional              functional
#   [127] functional              functional              functional
#   [130] functional              functional              functional
#   [133] functional              non functional          functional
#   [136] functional              functional              functional
#   [139] functional              functional needs repair functional
#   [142] functional              non functional          functional
#   [145] functional              functional              non functional
#   [148] non functional          functional              non functional
#   [151] functional needs repair functional              functional
#   [154] functional              functional              functional
#   [157] functional              functional needs repair functional
#   [160] non functional          functional              functional
#   [163] non functional          non functional          functional
#   [166] non functional          functional              functional
#   [169] functional needs repair functional              non functional
#   [172] functional              non functional          functional needs repair
#   [175] functional              functional needs repair functional
#   [178] functional              functional needs repair functional
#   [181] non functional          functional              functional
#   [184] functional              non functional          functional
#   [187] functional              functional              non functional
#   [190] functional              functional              functional
#   [193] functional              functional              functional
#   [196] functional              functional              functional
#   [199] non functional          functional              functional
#   [202] functional              functional              functional
#   [205] non functional          non functional          functional
#   [208] functional              functional              functional
#   [211] non functional          functional              functional
#   [214] functional              functional              functional
#   [217] functional              functional              functional
#   [220] functional              functional              functional
#   [223] functional              functional              functional
#   [226] non functional          functional              functional
#   [229] non functional          functional              functional
#   [232] functional              functional              functional
#   [235] functional              functional              functional
#   [238] non functional          functional              functional
#   [241] functional              functional              non functional
#   [244] functional              functional              functional needs repair
#   [247] functional              functional needs repair functional
#   [250] functional              functional needs repair functional
#   [253] functional              functional              functional
#   [256] functional              functional              functional needs repair
#   [259] functional              functional              functional
#   [262] functional needs repair functional              functional needs repair
#   [265] functional              functional              functional
#   [268] non functional          functional              functional
#   [271] functional              non functional          functional
#   [274] functional              functional              functional
#   [277] functional              functional              functional
#   [280] functional              functional              functional
#   [283] functional              functional              functional
#   [286] functional              non functional          functional
#   [289] non functional          functional              functional
#   [292] functional              functional needs repair functional
#   [295] functional              functional              functional
#   [298] functional              functional              functional
#   [301] non functional          functional              non functional
#   [304] non functional          functional needs repair non functional
#   [307] functional              non functional          functional
#   [310] functional              functional              non functional
#   [313] functional needs repair functional              functional
#   [316] functional              functional              functional
#   [319] non functional          functional              functional
#   [322] functional              functional              functional
#   [325] functional              functional              functional
#   [328] functional              functional              functional
#   [331] functional              functional              functional
#   [334] functional              functional              functional
#   [337] functional              functional              functional
#   [340] non functional          non functional          functional
#   [343] functional needs repair functional              non functional
#   [346] functional              functional              functional
#   [349] functional              functional              functional
#   [352] functional              functional              functional
#   [355] functional              functional              functional
#   [358] functional              functional              functional
#   [361] functional              functional needs repair functional
#   [364] functional              functional              functional
#   [367] functional              functional              functional
#   [370] functional              non functional          functional
#   [373] functional needs repair non functional          functional
#   [376] functional              functional              non functional
#   [379] functional              functional              functional
#   [382] functional needs repair functional              non functional
#   [385] functional              functional              functional
#   [388] functional              functional              functional
#   [391] non functional          functional              functional
#   [394] functional              functional              functional
#   [397] functional              non functional          functional
#   [400] functional              functional              non functional
#   [403] functional              functional              functional
#   [406] functional              functional              functional
#   [409] functional              non functional          functional
#   [412] functional              functional              functional
#   [415] functional needs repair functional              functional needs repair
#   [418] functional              functional              functional
#   [421] functional              functional              functional
#   [424] functional              functional needs repair functional
#   [427] functional              functional              non functional
#   [430] functional              functional              functional
#   [433] functional              non functional          non functional
#   [436] functional needs repair functional              functional needs repair
#   [439] functional              functional              functional
#   [442] non functional          functional              non functional
#   [445] functional              functional              non functional
#   [448] non functional          functional              functional
#   [451] functional              non functional          functional needs repair
#   [454] functional              functional              non functional
#   [457] functional              non functional          functional
#   [460] functional              functional              non functional
#   [463] functional              functional              non functional
#   [466] functional              functional              functional
#   [469] non functional          non functional          functional
#   [472] functional              non functional          functional
#   [475] functional needs repair functional              functional
#   [478] functional              functional              non functional
#   [481] functional              functional              functional needs repair
#   [484] non functional          functional              functional
#   [487] non functional          functional              functional
#   [490] functional              functional              non functional
#   [493] functional              functional              functional needs repair
#   [496] functional              functional needs repair functional
#   [499] non functional          non functional          functional
#   [502] functional              non functional          functional
#   [505] functional needs repair functional              functional
#   [508] functional              non functional          functional
#   [511] functional              functional              functional
#   [514] functional              non functional          functional
#   [517] functional needs repair functional              functional
#   [520] functional needs repair non functional          functional
#   [523] functional              functional              non functional
#   [526] functional              functional              functional
#   [529] functional              functional              functional needs repair
#   [532] functional              functional              functional
#   [535] functional              non functional          functional
#   [538] functional              functional              non functional
#   [541] functional              functional              non functional
#   [544] functional              non functional          non functional
#   [547] functional              functional needs repair functional
#   [550] functional needs repair functional              functional
#   [553] functional              functional              functional
#   [556] functional              functional              functional
#   [559] functional              functional              functional
#   [562] functional              functional              functional
#   [565] functional              functional              functional
#   [568] functional needs repair functional              functional
#   [571] functional              functional              non functional
#   [574] functional              functional              functional
#   [577] functional              functional              functional
#   [580] functional              functional              functional
#   [583] functional              functional              functional
#   [586] functional              functional              functional
#   [589] functional              functional              functional
#   [592] functional              functional              functional
#   [595] functional              functional              non functional
#   [598] functional              non functional          functional
#   [601] functional              functional              functional needs repair
#   [604] functional              functional              functional
#   [607] functional              non functional          functional
#   [610] non functional          functional              functional
#   [613] non functional          functional              non functional
#   [616] functional              non functional          functional
#   [619] functional              functional              functional
#   [622] functional              non functional          functional
#   [625] functional              non functional          functional
#   [628] functional              functional              functional needs repair
#   [631] functional              functional              functional
#   [634] functional              functional              functional
#   [637] functional              non functional          functional
#   [640] functional needs repair functional              functional
#   [643] functional              functional              functional
#   [646] functional              functional              functional
#   [649] functional needs repair non functional          functional
#   [652] functional              functional              non functional
#   [655] non functional          functional              functional
#   [658] functional              functional              functional
#   [661] functional              functional              functional
#   [664] functional              functional              functional needs repair
#   [667] functional              functional needs repair non functional
#   [670] non functional          functional              functional
#   [673] functional              functional              functional
#   [676] functional              non functional          functional needs repair
#   [679] functional              functional              functional
#   [682] functional              functional              functional
#   [685] functional              functional              functional
#   [688] non functional          non functional          functional
#   [691] functional              functional              non functional
#   [694] non functional          functional              functional
#   [697] functional              non functional          functional
#   [700] functional              functional              functional
#   [703] functional              functional              functional
#   [706] functional              functional              functional
#   [709] functional              functional              functional
#   [712] functional              non functional          non functional
#   [715] functional              functional              non functional
#   [718] functional              non functional          functional
#   [721] functional needs repair functional              non functional
#   [724] functional              functional              functional
#   [727] functional              functional              non functional
#   [730] functional              functional              functional
#   [733] non functional          functional              functional
#   [736] non functional          functional              functional
#   [739] functional              functional              non functional
#   [742] functional              functional              functional
#   [745] non functional          functional              functional
#   [748] functional              non functional          functional needs repair
#   [751] functional              functional              functional
#   [754] functional              functional              functional
#   [757] non functional          functional              functional needs repair
#   [760] non functional          non functional          functional
#   [763] functional              non functional          functional
#   [766] functional              functional              functional
#   [769] functional              functional              functional
#   [772] functional              functional              functional
#   [775] functional              functional              non functional
#   [778] functional              non functional          functional
#   [781] functional              non functional          functional
#   [784] functional              functional              functional
#   [787] functional needs repair functional              functional
#   [790] non functional          functional              functional
#   [793] functional needs repair functional              non functional
#   [796] functional              functional              functional
#   [799] functional              functional              functional
#   [802] functional              functional              functional
#   [805] functional              functional              functional
#   [808] functional              non functional          functional needs repair
#   [811] functional              functional              functional
#   [814] functional              functional              functional
#   [817] functional              functional              functional
#   [820] functional              functional              functional
#   [823] functional              functional              functional
#   [826] functional              functional              functional
#   [829] functional              non functional          functional
#   [832] functional              functional              functional
#   [835] functional              functional              functional
#   [838] functional              functional              functional
#   [841] functional              functional              functional
#   [844] functional              functional needs repair functional
#   [847] functional              functional              functional
#   [850] functional              functional              functional
#   [853] functional              functional              functional
#   [856] non functional          functional              functional
#   [859] functional              functional              functional
#   [862] functional              functional              functional
#   [865] non functional          functional              non functional
#   [868] functional needs repair functional              functional
#   [871] functional needs repair functional              functional
#   [874] functional needs repair functional              non functional
#   [877] functional              functional              functional
#   [880] functional              functional              non functional
#   [883] functional              functional              functional
#   [886] non functional          functional              functional
#   [889] functional              functional              functional
#   [892] functional needs repair functional              non functional
#   [895] functional              functional              functional
#   [898] functional              functional              functional
#   [901] functional              functional              functional
#   [904] functional              functional              functional
#   [907] functional              functional              functional
#   [910] functional needs repair functional              functional
#   [913] functional              functional              functional needs repair
#   [916] functional              functional              functional
#   [919] non functional          non functional          functional
#   [922] functional              non functional          non functional
#   [925] functional              functional              functional
#   [928] functional              functional              functional
#   [931] functional              functional              non functional
#   [934] non functional          non functional          functional
#   [937] functional              functional              functional needs repair
#   [940] non functional          functional              functional
#   [943] functional              functional              functional needs repair
#   [946] functional              functional              functional
#   [949] functional needs repair non functional          functional
#   [952] non functional          functional              functional
#   [955] functional              functional              functional
#   [958] functional              functional              functional
#   [961] functional              functional              functional needs repair
#   [964] non functional          functional              non functional
#   [967] non functional          functional              functional
#   [970] non functional          functional              functional
#   [973] functional              functional              functional
#   [976] functional              functional              functional
#   [979] functional              functional              functional
#   [982] functional              functional              functional
#   [985] functional              functional              functional
#   [988] functional              functional              functional
#   [991] functional              functional              functional
#   [994] functional              non functional          functional
#   [997] functional              functional              functional
#  [1000] functional              functional              functional
#  [1003] functional              functional              functional
#  [1006] functional              functional              functional
#  [1009] functional              functional              functional needs repair
#  [1012] functional              functional              functional
#  [1015] functional needs repair non functional          functional needs repair
#  [1018] functional              functional              non functional
#  [1021] non functional          functional              functional
#  [1024] functional needs repair functional              functional
#  [1027] non functional          functional              functional
#  [1030] functional              functional              functional
#  [1033] functional              non functional          functional
#  [1036] non functional          functional              functional
#  [1039] functional needs repair functional              functional
#  [1042] functional              functional              non functional
#  [1045] non functional          functional              functional
#  [1048] functional              functional              functional
#  [1051] functional              functional needs repair functional
#  [1054] non functional          functional              functional
#  [1057] functional              functional              functional needs repair
#  [1060] non functional          functional              non functional
#  [1063] functional              functional              functional
#  [1066] non functional          functional              non functional
#  [1069] functional              non functional          functional
#  [1072] functional              functional              functional
#  [1075] functional              non functional          non functional
#  [1078] functional              functional              functional
#  [1081] functional              non functional          functional needs repair
#  [1084] functional              functional              functional needs repair
#  [1087] functional needs repair functional              functional
#  [1090] functional              functional              functional
#  [1093] functional              functional needs repair functional
#  [1096] functional              functional              functional
#  [1099] functional              functional              functional
#  [1102] functional needs repair non functional          functional
#  [1105] functional              non functional          functional needs repair
#  [1108] functional needs repair functional              functional
#  [1111] functional              functional              non functional
#  [1114] functional              functional              functional needs repair
#  [1117] functional              functional              functional
#  [1120] non functional          functional              functional
#  [1123] functional              functional              functional
#  [1126] functional              functional              non functional
#  [1129] non functional          functional              non functional
#  [1132] functional              functional              non functional
#  [1135] functional              functional              functional
#  [1138] functional              functional              functional needs repair
#  [1141] functional              functional              functional
#  [1144] functional needs repair functional              functional needs repair
#  [1147] functional              functional              functional
#  [1150] functional              functional              functional
#  [1153] functional              non functional          functional
#  [1156] functional              functional              functional
#  [1159] functional              functional              functional
#  [1162] functional              functional              functional
#  [1165] functional              functional              functional
#  [1168] non functional          functional              non functional
#  [1171] functional              functional              non functional
#  [1174] functional              functional              non functional
#  [1177] non functional          functional              functional
#  [1180] functional              functional              functional
#  [1183] non functional          functional              functional
#  [1186] functional              functional              functional
#  [1189] functional              functional              functional
#  [1192] functional              functional              functional
#  [1195] functional              functional              non functional
#  [1198] functional              non functional          non functional
#  [1201] functional              non functional          functional
#  [1204] functional              functional              non functional
#  [1207] functional              non functional          functional
#  [1210] functional              functional              functional
#  [1213] functional              functional              functional
#  [1216] functional              functional              functional
#  [1219] functional              functional              functional
#  [1222] non functional          functional              functional
#  [1225] functional              functional              functional
#  [1228] non functional          functional              functional
#  [1231] functional              functional              non functional
#  [1234] functional              functional              functional
#  [1237] functional              functional              non functional
#  [1240] functional              functional              functional
#  [1243] functional              non functional          non functional
#  [1246] non functional          functional              functional
#  [1249] functional              non functional          functional
#  [1252] functional              functional needs repair functional
#  [1255] functional needs repair functional              non functional
#  [1258] functional              functional              functional
#  [1261] functional              non functional          functional
#  [1264] functional              non functional          non functional
#  [1267] functional              functional              functional
#  [1270] functional              functional              functional
#  [1273] functional needs repair functional              non functional
#  [1276] functional              functional              functional needs repair
#  [1279] functional              non functional          functional
#  [1282] functional              functional              non functional
#  [1285] functional              functional              functional
#  [1288] functional              functional              functional
#  [1291] functional              functional              functional
#  [1294] functional              functional              functional
#  [1297] functional              functional              functional
#  [1300] non functional          functional              functional
#  [1303] functional              functional              functional
#  [1306] non functional          functional              functional needs repair
#  [1309] functional              functional              functional
#  [1312] functional              non functional          functional needs repair
#  [1315] functional              functional              functional
#  [1318] functional              functional              non functional
#  [1321] functional needs repair functional              functional
#  [1324] functional              functional              functional needs repair
#  [1327] functional              functional              non functional
#  [1330] non functional          non functional          functional needs repair
#  [1333] functional              functional              functional
#  [1336] functional              functional              functional
#  [1339] functional needs repair functional              functional
#  [1342] functional              functional              functional
#  [1345] functional              functional              functional
#  [1348] functional              non functional          functional
#  [1351] functional              non functional          non functional
#  [1354] functional              functional              functional
#  [1357] functional              functional              non functional
#  [1360] functional              non functional          functional
#  [1363] non functional          functional              functional
#  [1366] non functional          non functional          functional
#  [1369] functional              functional              functional needs repair
#  [1372] functional              non functional          functional
#  [1375] functional needs repair functional              non functional
#  [1378] functional              functional              non functional
#  [1381] functional              functional              functional
#  [1384] non functional          functional              non functional
#  [1387] functional              functional              functional
#  [1390] functional needs repair functional              functional
#  [1393] functional              functional              functional
#  [1396] non functional          functional              functional
#  [1399] functional              functional              functional
#  [1402] functional              non functional          non functional
#  [1405] functional needs repair functional needs repair functional needs repair
#  [1408] functional              functional              functional
#  [1411] non functional          functional              functional
#  [1414] functional              functional              non functional
#  [1417] functional              non functional          functional
#  [1420] functional              functional              functional
#  [1423] functional              functional needs repair functional
#  [1426] functional              functional              functional
#  [1429] functional              functional              functional needs repair
#  [1432] functional needs repair non functional          functional
#  [1435] functional              functional              functional
#  [1438] functional              functional              functional
#  [1441] functional              functional              functional
#  [1444] functional needs repair functional needs repair functional
#  [1447] non functional          functional              functional
#  [1450] functional              non functional          functional
#  [1453] functional needs repair functional              functional
#  [1456] functional              non functional          functional needs repair
#  [1459] functional              functional              functional
#  [1462] functional              functional needs repair functional
#  [1465] non functional          functional              non functional
#  [1468] non functional          non functional          functional
#  [1471] functional              functional              functional
#  [1474] functional              functional              non functional
#  [1477] functional              functional              functional
#  [1480] functional              functional needs repair functional
#  [1483] functional              functional              functional
#  [1486] functional needs repair functional              functional
#  [1489] functional              non functional          functional
#  [1492] functional              functional              non functional
#  [1495] functional              functional needs repair functional
#  [1498] functional              non functional          functional needs repair
#  [1501] functional              functional needs repair functional
#  [1504] functional              functional              functional
#  [1507] non functional          functional              non functional
#  [1510] non functional          functional              functional
#  [1513] functional              non functional          functional
#  [1516] functional              functional              functional needs repair
#  [1519] functional              functional              functional
#  [1522] functional              functional              functional
#  [1525] functional              non functional          functional
#  [1528] functional              non functional          functional
#  [1531] functional              non functional          non functional
#  [1534] functional              functional              non functional
#  [1537] non functional          functional              functional
#  [1540] functional              functional              functional
#  [1543] functional              functional              functional
#  [1546] functional              functional              functional needs repair
#  [1549] functional              functional              non functional
#  [1552] functional              non functional          functional
#  [1555] functional              functional              functional
#  [1558] functional              non functional          functional
#  [1561] functional              functional              functional
#  [1564] functional              functional needs repair functional
#  [1567] functional              non functional          functional
#  [1570] functional              functional              functional
#  [1573] functional              non functional          functional
#  [1576] functional needs repair functional              functional
#  [1579] functional              functional              functional
#  [1582] functional              functional              functional
#  [1585] functional              functional              functional
#  [1588] functional              functional              non functional
#  [1591] functional              functional              functional
#  [1594] functional needs repair functional              functional
#  [1597] functional              functional              non functional
#  [1600] functional              functional needs repair functional
#  [1603] functional              non functional          functional
#  [1606] functional needs repair functional              functional
#  [1609] functional              non functional          non functional
#  [1612] functional              non functional          functional
#  [1615] functional              functional              functional
#  [1618] functional              functional              functional
#  [1621] functional              functional              functional
#  [1624] functional              non functional          functional
#  [1627] functional needs repair functional              functional
#  [1630] functional              non functional          functional
#  [1633] functional              functional              functional
#  [1636] non functional          functional              functional
#  [1639] functional              functional              functional
#  [1642] non functional          functional              functional
#  [1645] functional              functional              functional
#  [1648] functional              functional              functional
#  [1651] functional              functional              functional
#  [1654] functional              functional              functional
#  [1657] functional              functional              functional
#  [1660] functional              functional              functional
#  [1663] functional              functional              functional
#  [1666] functional              functional needs repair functional needs repair
#  [1669] functional needs repair functional              functional
#  [1672] functional              functional              functional
#  [1675] functional              functional needs repair functional
#  [1678] functional              non functional          non functional
#  [1681] functional              non functional          functional
#  [1684] non functional          functional needs repair functional
#  [1687] functional              functional              functional needs repair
#  [1690] functional              functional              functional
#  [1693] functional              functional              functional
#  [1696] non functional          functional              functional
#  [1699] functional needs repair functional needs repair functional
#  [1702] functional needs repair functional              non functional
#  [1705] functional              functional              functional
#  [1708] functional              functional              functional
#  [1711] functional needs repair functional              non functional
#  [1714] functional              functional              functional
#  [1717] functional              functional              functional
#  [1720] functional              functional              functional
#  [1723] functional              functional needs repair functional
#  [1726] functional              functional              non functional
#  [1729] functional              functional              non functional
#  [1732] non functional          functional              non functional
#  [1735] non functional          functional needs repair functional needs repair
#  [1738] functional              functional              non functional
#  [1741] functional              functional              functional
#  [1744] functional              non functional          functional
#  [1747] functional              non functional          functional
#  [1750] functional              functional needs repair functional
#  [1753] functional              functional              functional
#  [1756] functional              functional              functional
#  [1759] functional              functional              functional
#  [1762] functional              functional              non functional
#  [1765] non functional          non functional          functional
#  [1768] functional              functional              functional
#  [1771] functional              functional              functional needs repair
#  [1774] functional              functional              functional
#  [1777] functional              non functional          functional
#  [1780] functional              functional              functional
#  [1783] functional              functional              functional
#  [1786] functional              functional              functional needs repair
#  [1789] functional              functional              non functional
#  [1792] functional needs repair non functional          functional
#  [1795] functional              functional              functional
#  [1798] functional              non functional          non functional
# ...
# [14254] non functional          functional              functional
# [14257] non functional          functional              functional
# [14260] non functional          functional              functional
# [14263] functional              functional              non functional
# [14266] functional              functional              functional
# [14269] functional              functional              functional
# [14272] functional              functional              functional
# [14275] functional              functional              functional
# [14278] functional              functional              functional
# [14281] functional              non functional          functional
# [14284] functional              functional              functional
# [14287] functional              functional needs repair functional needs repair
# [14290] functional needs repair functional              functional
# [14293] functional              functional              functional
# [14296] functional needs repair functional              functional
# [14299] functional              functional              functional
# [14302] functional              functional              functional needs repair
# [14305] functional              non functional          functional
# [14308] functional              non functional          functional
# [14311] functional              functional              non functional
# [14314] non functional          functional              functional needs repair
# [14317] functional              functional              functional
# [14320] functional              functional              functional
# [14323] functional              functional              non functional
# [14326] functional needs repair functional              functional
# [14329] functional              functional              non functional
# [14332] functional              functional              functional needs repair
# [14335] functional              functional              non functional
# [14338] functional              functional              functional
# [14341] non functional          functional              functional
# [14344] non functional          functional              functional
# [14347] functional              functional              functional
# [14350] functional              functional              functional
# [14353] non functional          non functional          functional
# [14356] functional              functional              functional
# [14359] functional              functional              functional
# [14362] functional needs repair functional              non functional
# [14365] functional              functional              functional needs repair
# [14368] functional needs repair functional              non functional
# [14371] functional              functional              functional
# [14374] functional              non functional          functional
# [14377] functional              functional              functional
# [14380] functional              functional              functional
# [14383] functional              non functional          non functional
# [14386] functional              functional              functional
# [14389] functional              functional              non functional
# [14392] non functional          functional              functional
# [14395] functional              functional              functional
# [14398] functional needs repair functional              functional
# [14401] functional              functional              non functional
# [14404] functional              functional              functional
# [14407] functional              functional              functional
# [14410] functional              functional              non functional
# [14413] non functional          functional              non functional
# [14416] non functional          functional              non functional
# [14419] functional              functional              functional
# [14422] functional              non functional          functional
# [14425] functional              functional              functional
# [14428] functional              functional              functional
# [14431] non functional          functional              functional
# [14434] functional              functional              functional
# [14437] functional              functional              functional
# [14440] functional              functional              functional
# [14443] functional              functional              functional
# [14446] functional needs repair non functional          functional
# [14449] non functional          non functional          functional
# [14452] functional              functional              non functional
# [14455] functional              functional              functional needs repair
# [14458] functional needs repair functional              non functional
# [14461] non functional          functional              non functional
# [14464] functional              non functional          functional
# [14467] functional needs repair functional              functional
# [14470] functional              functional              non functional
# [14473] functional              non functional          functional
# [14476] functional needs repair functional              non functional
# [14479] functional              functional              functional
# [14482] functional              functional              functional
# [14485] functional              functional              functional
# [14488] functional              non functional          non functional
# [14491] functional              functional              functional
# [14494] functional              functional              functional
# [14497] functional              functional              functional needs repair
# [14500] functional              functional              functional
# [14503] functional              non functional          functional
# [14506] non functional          functional              functional
# [14509] functional              functional              non functional
# [14512] functional              functional needs repair functional
# [14515] functional              functional              non functional
# [14518] functional              functional needs repair functional
# [14521] functional              functional              functional
# [14524] functional              functional              functional
# [14527] functional              functional needs repair functional
# [14530] functional              functional              functional
# [14533] functional              functional              functional
# [14536] non functional          functional              functional
# [14539] functional              functional              functional
# [14542] functional              functional              functional
# [14545] functional              functional              non functional
# [14548] functional              functional              functional
# [14551] non functional          functional              functional
# [14554] functional              functional              functional
# [14557] functional              functional              functional
# [14560] functional              functional              functional
# [14563] functional              functional              non functional
# [14566] functional needs repair functional              functional
# [14569] functional              non functional          functional
# [14572] non functional          non functional          functional
# [14575] functional              non functional          functional
# [14578] functional              functional              non functional
# [14581] functional              functional              functional
# [14584] functional              functional              functional
# [14587] non functional          non functional          functional
# [14590] functional              functional              non functional
# [14593] functional              functional              functional
# [14596] functional              functional              functional
# [14599] functional              functional              non functional
# [14602] functional              functional needs repair functional
# [14605] functional              functional              functional
# [14608] functional              functional needs repair functional needs repair
# [14611] functional              functional needs repair functional
# [14614] non functional          functional              functional
# [14617] functional              functional              functional
# [14620] non functional          functional              functional
# [14623] functional              non functional          functional needs repair
# [14626] functional needs repair functional              non functional
# [14629] functional              functional              functional
# [14632] functional              non functional          functional
# [14635] functional needs repair functional needs repair functional
# [14638] functional              non functional          non functional
# [14641] functional needs repair functional needs repair functional
# [14644] functional              functional              functional
# [14647] functional              functional              functional
# [14650] functional needs repair non functional          functional
# [14653] functional              functional needs repair functional
# [14656] functional              functional              non functional
# [14659] functional              functional              functional
# [14662] functional              functional              functional
# [14665] non functional          functional              functional
# [14668] functional              non functional          functional
# [14671] functional              non functional          functional
# [14674] functional              functional              non functional
# [14677] functional needs repair non functional          functional
# [14680] non functional          functional              functional
# [14683] functional              functional              functional
# [14686] functional              functional              functional
# [14689] functional              functional              non functional
# [14692] functional              functional              functional
# [14695] functional              functional              non functional
# [14698] functional              functional              functional
# [14701] functional              functional              functional
# [14704] functional              functional              functional
# [14707] non functional          non functional          functional
# [14710] functional              functional needs repair non functional
# [14713] non functional          functional needs repair functional needs repair
# [14716] functional              functional              functional
# [14719] functional              functional              functional
# [14722] functional              functional              functional
# [14725] functional              functional needs repair functional
# [14728] functional              functional              functional
# [14731] functional              non functional          functional
# [14734] functional              functional needs repair functional
# [14737] functional              functional              functional
# [14740] functional              functional              functional
# [14743] functional              functional              functional
# [14746] functional              functional              non functional
# [14749] non functional          functional              functional
# [14752] functional              functional needs repair functional
# [14755] functional              functional              functional
# [14758] functional              functional              non functional
# [14761] functional              functional              functional
# [14764] functional              functional              functional
# [14767] functional needs repair non functional          non functional
# [14770] functional              functional              functional
# [14773] functional              non functional          non functional
# [14776] functional              functional              functional needs repair
# [14779] functional              functional              functional
# [14782] non functional          functional              functional
# [14785] functional              functional              functional
# [14788] functional              functional needs repair functional
# [14791] functional needs repair non functional          non functional
# [14794] functional              functional              functional needs repair
# [14797] functional              functional              functional
# [14800] non functional          functional              functional
# [14803] functional              functional              non functional
# [14806] functional              functional              functional
# [14809] functional              functional              functional
# [14812] functional              functional              functional
# [14815] functional              functional              functional
# [14818] non functional          functional              functional
# [14821] functional              functional              non functional
# [14824] functional              functional              non functional
# [14827] functional              functional              non functional
# [14830] functional              functional              functional needs repair
# [14833] functional              functional              functional
# [14836] functional              functional              functional
# [14839] functional              functional              functional
# [14842] functional needs repair functional              functional
# [14845] functional              functional              functional
# [14848] functional              functional              non functional
# Levels: functional functional needs repair non functional

# %%
# GRADIENT BOOSTING
library(gbm)


model <- gbm(formula = status_group~., distribution = "multinomial", data = data_train, n.trees = 5000,
            interaction.depth = 4, shrinkage = 0.01, cv.folds = 10, n.minobsinnode = 10)

# rf_model <- randomForest(status_group~., data= data_train) # what we need to change according of the model
# rf_model
rf_predict_unseen <- predict(model, newdata = data_test, type="response", n.trees = 5000)

# rf_predict_unseen
# cm = confusionMatrix(data_test$status_group, as.factor(labels))

status_group <- colnames(rf_predict_unseen)[apply(rf_predict_unseen, 1, which.max)]

rf_data_predict <- cbind(data_test[1], status_group)
rf_data_predict
# cm = confusionMatrix(data_test$status_group, as.factor(labels))
# print(cm)
# result <- data.frame(data_test$status_group, labels)
# print(result)
# status_group <-rf_predict_unseen

# rf_data_predict <- test_set_values


# rf_data_predict <- cbind(rf_data_predict[1],status_group)


# rf_data_predict

write.csv(rf_data_predict,"boosting.csv",row.names = FALSE)
# Out:
# Warning message:
# "Setting `distribution = "multinomial"` is ill-advised as it is currently broken. It exists only for backwards compatibility. Use at your own risk."
